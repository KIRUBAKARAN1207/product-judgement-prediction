# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd 
import random

# %% [markdown]
# # image from which dataframe to be created

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
imgee=image.load_img(r"C:\Users\KIRUBA KARAN\OneDrive\Pictures\83208e854acb7513acfde1bdb2ff4682.jpg")
plt.figure(figsize=(25,25))
plt.imshow(imgee)

# %% [markdown]
# # creating dataframe by random libraray

# %%
a= []
b= []
for i in range(0, 1500):
    x = round(random.uniform(9.9,10.1), 2)
    y = round(random.uniform(9.9,10.1), 2)
    a.append(x)
    b.append(y)
di1=np.array(a)
di2=np.array(b)

c = []
for i in range(0, 1500):
    x = round(random.uniform(24.8,25.2), 2)
    c.append(x)
r1=np.array(c)

d = []
for i in range(0, 1500):
    x = round(random.uniform(30.8,31.2), 2)
    d.append(x)
r2=np.array(d)

e = []
for i in range(0, 1500):
    x = round(random.uniform(29.8,30.2), 2)
    e.append(x)
r3=np.array(e)

f = []
for i in range(0, 1500):
    x = round(random.uniform(5.9,6.1), 2)
    f.append(x)
r4=np.array(f)

g = []
for i in range(0, 1500):
    x = round(random.uniform(19.8,20.2), 2)
    g.append(x)
r5=np.array(g)

h = []
for i in range(0, 1500):
    x = round(random.uniform(65.62,66.62), 2)
    h.append(x)
dis1=np.array(h)

ii = []
for i in range(0, 1500):
    x = round(random.uniform(21.7,22.3), 2)
    ii.append(x)
dis2=np.array(ii)

j = []
for i in range(0, 1500):
    x = round(random.uniform(35.7,36.3), 2)
    j.append(x)
dis3=np.array(j)

k = []
for i in range(0, 1500):
    x = round(random.uniform(99.5,100.5), 2)
    k.append(x)
dis4=np.array(k)

l = []
for i in range(0, 1500):
    x = round(random.uniform(124.5,125.5), 2)
    l.append(x)
dis5=np.array(l)

m = []
for i in range(0, 1500):
    x = round(random.uniform(179.2,180.8), 2)
    m.append(x)
dis6=np.array(m)

n = []
for i in range(0, 1500):
    x = round(random.uniform(37.7,38.3), 2)
    n.append(x)
dis7=np.array(n)

o = []
for i in range(0, 1500):
    x = round(random.uniform(14.7,15.3), 2)
    o.append(x)
dis8=np.array(o)

p = []
for i in range(0, 1500):
    x = round(random.uniform(21.7,22.3), 2)
    p.append(x)
dis9=np.array(p)

# %%
a= []
b= []
for i in range(0, 250):
    x = round(random.uniform(8,9.8), 2)
    y = round(random.uniform(8,9.8), 2)
    a.append(x)
    b.append(y)
di11=np.array(a)
di21=np.array(b)

c = []
for i in range(0, 250):
    x = round(random.uniform(23,24.8), 2)
    c.append(x)
r11=np.array(c)

d = []
for i in range(0, 250):
    x = round(random.uniform(29,30.8), 2)
    d.append(x)
r21=np.array(d)

e = []
for i in range(0, 250):
    x = round(random.uniform(28,29.8), 2)
    e.append(x)
r31=np.array(e)

f = []
for i in range(0, 250):
    x = round(random.uniform(4,5.9), 2)
    f.append(x)
r41=np.array(f)

g = []
for i in range(0, 250):
    x = round(random.uniform(18,19.8), 2)
    g.append(x)
r51=np.array(g)

h = []
for i in range(0, 250):
    x = round(random.uniform(64,65.62), 2)
    h.append(x)
dis11=np.array(h)

ii = []
for i in range(0, 250):
    x = round(random.uniform(20,21.7), 2)
    ii.append(x)
dis21=np.array(ii)

j = []
for i in range(0, 250):
    x = round(random.uniform(34,35.7), 2)
    j.append(x)
dis31=np.array(j)

k = []
for i in range(0, 250):
    x = round(random.uniform(98,99.5), 2)
    k.append(x)
dis41=np.array(k)

l = []
for i in range(0, 250):
    x = round(random.uniform(123,124.5), 2)
    l.append(x)
dis51=np.array(l)

m = []
for i in range(0, 250):
    x = round(random.uniform(178,179.2), 2)
    m.append(x)
dis61=np.array(m)

n = []
for i in range(0, 250):
    x = round(random.uniform(36,37.7), 2)
    n.append(x)
dis71=np.array(n)

o = []
for i in range(0, 250):
    x = round(random.uniform(13,14.7), 2)
    o.append(x)
dis81=np.array(o)

p = []
for i in range(0, 250):
    x = round(random.uniform(20,21.7), 2)
    p.append(x)
dis91=np.array(p)

# %%
a= []
b= []
for i in range(0, 250):
    x = round(random.uniform(11.3,10.1), 2)
    y = round(random.uniform(11.3,10.1), 2)
    a.append(x)
    b.append(y)
di12=np.array(a)
di22=np.array(b)

c = []
for i in range(0, 250):
    x = round(random.uniform(27,25.2), 2)
    c.append(x)
r12=np.array(c)

d = []
for i in range(0, 250):
    x = round(random.uniform(33,31.2), 2)
    d.append(x)
r22=np.array(d)

e = []
for i in range(0, 250):
    x = round(random.uniform(31.5,30.2), 2)
    e.append(x)
r32=np.array(e)

f = []
for i in range(0, 250):
    x = round(random.uniform(7.5,6.1), 2)
    f.append(x)
r42=np.array(f)

g = []
for i in range(0, 250):
    x = round(random.uniform(22.5,20.2), 2)
    g.append(x)
r52=np.array(g)

h = []
for i in range(0, 250):
    x = round(random.uniform(64,65.62), 2)
    h.append(x)
dis12=np.array(h)

ii = []
for i in range(0, 250):
    x = round(random.uniform(24,22.3), 2)
    ii.append(x)
dis22=np.array(ii)

j = []
for i in range(0, 250):
    x = round(random.uniform(38,36.3), 2)
    j.append(x)
dis32=np.array(j)

k = []
for i in range(0, 250):
    x = round(random.uniform(102,100.5), 2)
    k.append(x)
dis42=np.array(k)

l = []
for i in range(0, 250):
    x = round(random.uniform(127,125.5), 2)
    l.append(x)
dis52=np.array(l)

m = []
for i in range(0, 250):
    x = round(random.uniform(182,180.8), 2)
    m.append(x)
dis62=np.array(m)

n = []
for i in range(0, 250):
    x = round(random.uniform(41,38.3), 2)
    n.append(x)
dis72=np.array(n)

o = []
for i in range(0, 250):
    x = round(random.uniform(17,15.3), 2)
    o.append(x)
dis82=np.array(o)

p = []
for i in range(0, 250):
    x = round(random.uniform(24,22.3), 2)
    p.append(x)
dis92=np.array(p)

# %%
a= []
b= []
for i in range(0, 500):
    x = round(random.uniform(8.5,11), 2)
    y = round(random.uniform(8.5,11), 2)
    a.append(x)
    b.append(y)
di13=np.array(a)
di23=np.array(b)

c = []
for i in range(0, 500):
    x = round(random.uniform(24,26), 2)
    c.append(x)
r13=np.array(c)

d = []
for i in range(0, 500):
    x = round(random.uniform(29.5,32.3), 2)
    d.append(x)
r23=np.array(d)

e = []
for i in range(0, 500):
    x = round(random.uniform(28.8,31.2), 2)
    e.append(x)
r33=np.array(e)

f = []
for i in range(0, 500):
    x = round(random.uniform(4.9,7.1), 2)
    f.append(x)
r43=np.array(f)

g = []
for i in range(0, 500):
    x = round(random.uniform(18.8,21.2), 2)
    g.append(x)
r53=np.array(g)

h = []
for i in range(0, 500):
    x = round(random.uniform(64.62,67.5), 2)
    h.append(x)
dis13=np.array(h)

ii = []
for i in range(0, 500):
    x = round(random.uniform(20.7,23.3), 2)
    ii.append(x)
dis23=np.array(ii)

j = []
for i in range(0, 500):
    x = round(random.uniform(34.7,37.3), 2)
    j.append(x)
dis33=np.array(j)

k = []
for i in range(0, 500):
    x = round(random.uniform(98.5,101.5), 2)
    k.append(x)
dis43=np.array(k)

l = []
for i in range(0, 500):
    x = round(random.uniform(123.5,126.5), 2)
    l.append(x)
dis53=np.array(l)

m = []
for i in range(0, 500):
    x = round(random.uniform(178.2,181.8), 2)
    m.append(x)
dis63=np.array(m)

n = []
for i in range(0, 500):
    x = round(random.uniform(36.7,39.3), 2)
    n.append(x)
dis73=np.array(n)

o = []
for i in range(0, 500):
    x = round(random.uniform(13.7,16.3), 2)
    o.append(x)
dis83=np.array(o)

p = []
for i in range(0, 500):
    x = round(random.uniform(20.7,23.3), 2)
    p.append(x)
dis93=np.array(p)

# %%
ok=[]
for i in range(1500):
    i=1
    ok.append(i)
ok=np.array(ok)

# %%
ng1=[]
for i in range(250):
    i=0
    ng1.append(i)
ng1=np.array(ng1)

ng2=[]
for i in range(250):
    i=0
    ng2.append(i)
ng2=np.array(ng2)

# %%
dis2
# Out:
# array([21.82, 22.27, 21.75, ..., 21.87, 22.05, 21.73])

# %%
p1 = []
for i in range(0, 500):
    x = round(random.uniform(0,1))
    p1.append(x)
ng3=np.array(p1)

# %%
pis1={'dia1':di1,'dia2':di2,'radius1':r1,'radius2':r2,'radius3':r3,'radius4':r4,'radius5':r5,'distance1':dis1,'distance2':dis2,'distance3':dis3,'distance4':dis4,'distance5':dis5,'distance6':dis6,'distance7':dis7,'distance8':dis8,'distance9':dis9,'judgement':ok}

# %%
piston1=pd.DataFrame(pis1)
piston1
len(piston1)
# Out:
# 1500

# %%
pis3={'dia1':di12,'dia2':di22,'radius1':r12,'radius2':r22,'radius3':r32,'radius4':r42,'radius5':r52,'distance1':dis12,'distance2':dis22,'distance3':dis32,'distance4':dis42,'distance5':dis52,'distance6':dis62,'distance7':dis72,'distance8':dis82,'distance9':dis92,'judgement':ng2}
pis4={'dia1':di13,'dia2':di23,'radius1':r13,'radius2':r23,'radius3':r33,'radius4':r43,'radius5':r53,'distance1':dis13,'distance2':dis23,'distance3':dis33,'distance4':dis43,'distance5':dis53,'distance6':dis63,'distance7':dis73,'distance8':dis83,'distance9':dis93,'judgement':ng3}
pis2={'dia1':di11,'dia2':di21,'radius1':r11,'radius2':r21,'radius3':r31,'radius4':r41,'radius5':r51,'distance1':dis11,'distance2':dis21,'distance3':dis31,'distance4':dis41,'distance5':dis51,'distance6':dis61,'distance7':dis71,'distance8':dis81,'distance9':dis91,'judgement':ng1}

# %%
piston2,piston3,piston4=pd.DataFrame(pis2),pd.DataFrame(pis3),pd.DataFrame(pis4)

# %%
pistons2=pd.concat([piston2,piston3,piston4])

# %%
pistons2
# Out:
#       dia1   dia2  radius1  radius2  radius3  radius4  radius5  distance1  \
# 0     8.87   9.09    23.94    29.04    28.49     5.11    19.14      65.39
# 1     9.67   9.57    23.53    29.20    29.13     4.69    18.29      65.48
# 2     8.10   9.18    23.82    29.93    29.35     4.55    18.29      65.41
# 3     8.91   8.18    24.40    30.71    28.08     5.39    19.38      64.91
# 4     8.45   8.75    23.55    29.87    28.55     5.07    18.74      65.37
# ..     ...    ...      ...      ...      ...      ...      ...        ...
# 495   9.50   9.99    25.81    31.65    29.99     5.78    20.42      64.75
# 496   9.37  10.10    24.19    31.38    28.91     7.00    19.87      65.94
# 497  10.94   9.30    25.97    30.53    29.00     6.80    19.52      66.41
# 498   9.69  10.24    25.90    30.15    29.00     6.85    19.88      66.72
# 499   9.79  10.32    24.88    29.84    30.66     5.14    20.50      66.08
#
#      distance2  distance3  distance4  distance5  distance6  distance7  \
# ...

# %%
data=pd.concat([piston1,pistons2])

# %%
data
# Out:
#       dia1   dia2  radius1  radius2  radius3  radius4  radius5  distance1  \
# 0    10.01   9.96    24.91    30.83    30.00     5.97    20.08      66.44
# 1    10.09  10.02    25.00    30.81    29.98     6.07    20.04      66.32
# 2    10.07  10.09    24.91    31.08    30.01     6.07    19.87      66.45
# 3    10.07   9.93    24.98    31.03    30.09     5.98    19.81      66.10
# 4     9.98  10.09    24.92    30.97    30.13     5.93    20.05      65.69
# ..     ...    ...      ...      ...      ...      ...      ...        ...
# 495   9.50   9.99    25.81    31.65    29.99     5.78    20.42      64.75
# 496   9.37  10.10    24.19    31.38    28.91     7.00    19.87      65.94
# 497  10.94   9.30    25.97    30.53    29.00     6.80    19.52      66.41
# 498   9.69  10.24    25.90    30.15    29.00     6.85    19.88      66.72
# 499   9.79  10.32    24.88    29.84    30.66     5.14    20.50      66.08
#
#      distance2  distance3  distance4  distance5  distance6  distance7  \
# ...

# %%
df=data.sample(frac=1)

# %%
piston4[piston4['distance9']>21.7]
# Out:
#       dia1   dia2  radius1  radius2  radius3  radius4  radius5  distance1  \
# 1     8.73   8.83    24.30    31.09    29.94     6.73    19.69      64.65
# 2     8.86  10.16    24.25    30.73    29.21     5.54    21.13      67.30
# 3     9.21   9.46    24.34    30.29    29.56     5.82    19.90      64.84
# 4     8.60  10.22    25.50    29.86    31.05     6.66    18.92      66.54
# 5     8.62   8.55    24.10    30.02    30.17     5.71    19.33      67.23
# ..     ...    ...      ...      ...      ...      ...      ...        ...
# 490   8.75   9.94    24.52    30.12    30.37     5.69    21.13      65.13
# 492   9.95  10.32    25.41    31.53    28.83     5.81    20.90      65.91
# 493  10.79   9.53    25.02    30.20    29.85     5.78    21.07      64.76
# 495   9.50   9.99    25.81    31.65    29.99     5.78    20.42      64.75
# 498   9.69  10.24    25.90    30.15    29.00     6.85    19.88      66.72
#
#      distance2  distance3  distance4  distance5  distance6  distance7  \
# ...

# %%
df
# Out:
#       dia1   dia2  radius1  radius2  radius3  radius4  radius5  distance1  \
# 436  10.04  10.10    24.94    31.07    30.06     6.09    19.97      66.21
# 683   9.95   9.95    24.96    31.02    30.00     5.91    19.88      66.06
# 201   9.68   9.39    25.95    32.03    28.95     6.52    21.15      67.37
# 207  10.45  10.88    25.71    32.09    31.00     6.34    20.45      65.30
# 135  10.59   8.61    25.24    30.41    29.92     6.19    19.84      65.35
# ..     ...    ...      ...      ...      ...      ...      ...        ...
# 875  10.05   9.98    24.92    30.97    29.87     5.92    19.81      66.39
# 231  10.00  10.03    25.11    30.92    29.86     5.95    20.09      66.45
# 85    9.98  10.03    25.08    31.20    29.90     5.99    19.91      66.38
# 37   10.67  10.59    25.67    32.46    30.52     6.15    20.89      64.27
# 125   9.90  10.02    24.92    31.00    29.90     6.08    20.16      66.04
#
#      distance2  distance3  distance4  distance5  distance6  distance7  \
# ...

# %%
df.index=np.array([i for i in range(0,2500)])

# %%
df
# Out:
#        dia1   dia2  radius1  radius2  radius3  radius4  radius5  distance1  \
# 0     10.04  10.10    24.94    31.07    30.06     6.09    19.97      66.21
# 1      9.95   9.95    24.96    31.02    30.00     5.91    19.88      66.06
# 2      9.68   9.39    25.95    32.03    28.95     6.52    21.15      67.37
# 3     10.45  10.88    25.71    32.09    31.00     6.34    20.45      65.30
# 4     10.59   8.61    25.24    30.41    29.92     6.19    19.84      65.35
# ...     ...    ...      ...      ...      ...      ...      ...        ...
# 2495  10.05   9.98    24.92    30.97    29.87     5.92    19.81      66.39
# 2496  10.00  10.03    25.11    30.92    29.86     5.95    20.09      66.45
# 2497   9.98  10.03    25.08    31.20    29.90     5.99    19.91      66.38
# 2498  10.67  10.59    25.67    32.46    30.52     6.15    20.89      64.27
# 2499   9.90  10.02    24.92    31.00    29.90     6.08    20.16      66.04
#
# ...

# %% [markdown]
# # saving the dataframe

# %%
df.to_csv('piston_rod.csv')
